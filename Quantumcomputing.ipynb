# %% [markdown]
# <a href="https://colab.research.google.com/github/debjitroy19930810-crypto/Quantum-Computing-/blob/main/Quantumcomputing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_qsphere
import numpy as np

# %%
n = 1
qc = QuantumCircuit(n)
#qc.h(0)
s = Statevector.from_instruction(qc).data
print(s)
plot_state_qsphere(s)
# Out:
# [1.+0.j 0.+0.j]

# %%
n = 2
qc = QuantumCircuit(n)
qc.h(0)
qc.cx(0,1)# bells state
qc.x(0)
s = Statevector.from_instruction(qc).data
print(s)
plot_state_qsphere(s)
#qc.draw()
# Out:
# [0.        +0.j 0.70710678+0.j 0.70710678+0.j 0.        +0.j]
